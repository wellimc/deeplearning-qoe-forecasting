# %%
import os
import yaml
import pandas as pd
from pathlib import Path
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()

os.chdir("../scripts")

import preprocess, train, inference, interpret

# %%
with open("../model/params.yaml", "r") as params_file:
    params = yaml.safe_load(params_file)

data_dir = params['data_dir']

# %%
file_name = "Trepn_2022.04.04_183605_q360_total.csv"
data = preprocess.load_data(file_name)
data.head(3)
# Out:
#     Time       Min  Memory Usage  CPU Frequency  CPU Load  Wi-Fi State  \
# 0    146  00:00:00       1824916        1586000        40            3
# 1  10055  00:00:10       1824984        1586000        40            3
# 2  20038  00:00:20       1826428         902000        40            3
#
#    Wi-Fi RSSI Level  Screen Bright  Battery  GPS State  Quality  Download  \
# 0               -57              4       71          1      720       820
# 1               -57              4       71          1      720       820
# 2               -57              4       71          1      720       820
#
#    Upload
# 0      11
# 1      11
# 2      11

# %%
train_df, test_df = preprocess.prep_data(df=data, train_frac=0.6, plot_df=True)
# Out:
# Starting with data preparation...
# Completed.

# %%
print(train_df.shape)
print(test_df.shape)
train_df.head(10)
# Out:
# (139, 10)
# (93, 10)
#            Time  CPU Frequency  CPU Load  Memory Usage  Wi-Fi RSSI Level  \
# Time
# 146    0.000000       1.000000       0.0      0.739783             0.875
# 10055  0.007181       1.000000       0.0      0.740394             0.875
# 20038  0.014415       0.342308       0.0      0.753358             0.875
# 30025  0.021653       0.775000       0.0      0.683150             0.875
# 40037  0.028908       0.775000       0.0      0.348847             0.875
# 50026  0.036147       0.450000       0.0      0.585219             0.875
# 60067  0.043424       0.900000       0.0      0.533685             0.875
# 70064  0.050668       0.342308       0.0      0.689507             0.875
# 80051  0.057906       0.900000       0.0      0.056058             0.875
# 90042  0.065146       1.000000       0.0      0.765316             0.875
#
#        Quality  Screen Bright  Battery  Download  Upload
# Time
# 146        0.0            0.0      1.0       0.0     1.0
# 10055      0.0            0.0      1.0       0.0     1.0
# 20038      0.0            0.0      1.0       0.0     1.0
# 30025      0.0            0.0      1.0       0.0     1.0
# 40037      0.0            0.0      1.0       0.0     1.0
# 50026      0.0            0.0      1.0       0.0     1.0
# 60067      0.0            0.0      1.0       0.0     1.0
# 70064      0.0            0.0      1.0       0.0     1.0
# 80051      0.0            0.0      1.0       0.0     1.0
# 90042      0.0            0.0      1.0       0.0     1.0

# %%
test_df.head(10)
# Out:
#          Time  CPU Frequency  CPU Load  Memory Usage  Wi-Fi RSSI Level  \
# 139  1.007247       0.775000       0.0      0.746463            0.3125
# 140  1.014494       1.000000       0.0      0.676973            0.6250
# 141  1.021740       1.000000       0.0      0.743841            0.4375
# 142  1.028987       1.000000       0.0      0.536379            0.4375
# 143  1.036234       0.342308       0.0      0.722150            0.7500
# 144  1.043481       0.450000       0.0      0.316886            0.1875
# 145  1.050728       1.000000       0.0      0.563456            0.5625
# 146  1.057975       0.342308       0.0      0.734504            0.5625
# 147  1.065221       0.342308       0.0      0.250700            0.3750
# 148  1.072468       0.342308       0.0      0.574373            0.7500
#
#      Quality  Screen Bright   Battery  Download  Upload
# 139      0.0            1.0  0.000000       1.0     0.0
# 140      0.0            1.0  0.000000       1.0     0.0
# 141      0.0            1.0  0.000000       1.0     0.0
# 142      0.0            1.0  0.000000       1.0     0.0
# 143      0.0            1.0 -0.166667       1.0     0.0
# 144      0.0            1.0 -0.166667       1.0     0.0
# 145      0.0            1.0 -0.166667       1.0     0.0
# 146      0.0            1.0 -0.166667       1.0     0.0
# 147      0.0            1.0 -0.166667       1.0     0.0
# 148      0.0            1.0 -0.166667       1.0     0.0

# %%
plot_df = pd.read_csv(Path(data_dir, 'plot_df.csv'))
plot_df['Battery'] = plot_df.Battery
plot_df = plot_df.dropna()

# %%
plot_df['Battery'].plot(figsize=(12,6), rot=45, cmap='viridis')
plt.title('Battery Drain (%)')
plt.show()

# %%
fig, axes = plt.subplots(nrows=3, ncols=1)
plot_df['Battery'].plot(ax=axes[0], figsize=(12,6), rot=10, title='a. Bateery Level Change', sharex=True)
plot_df['Battery'].rolling(90).mean().plot(ax=axes[1], figsize=(12,6), rot=90, title='b. Mean', color='orange')
plot_df['Battery'].rolling(90).std().plot(ax=axes[2], figsize=(12,6), rot=0, title='c.  Standard Deviation', color='purple')
plt.show()

# %%
sequence_length = 10
batch_size = 2
n_epochs = 50
n_epochs_stop = 10

#sequence_length = 10
#batch_size = 5
#n_epochs = 200
#n_epochs_stop = 50
label_name = 'Battery'

# %%
hist = train.train_model(train_df, test_df, label_name, sequence_length, batch_size, n_epochs, n_epochs_stop)
# Out:
# Starting with model training...
# Epoch 1 train loss: 0.1449 test loss: 0.1534
# Epoch 2 train loss: 0.0681 test loss: 0.1226
# Epoch 3 train loss: 0.036 test loss: 0.1238
# Epoch 4 train loss: 0.039 test loss: 0.1149
# Epoch 5 train loss: 0.0409 test loss: 0.1019
# Epoch 6 train loss: 0.0406 test loss: 0.0915
# Epoch 7 train loss: 0.0397 test loss: 0.0762
# Epoch 8 train loss: 0.038 test loss: 0.0634
# Epoch 9 train loss: 0.0385 test loss: 0.0632
# Epoch 10 train loss: 0.0339 test loss: 0.0594
# Epoch 11 train loss: 0.0325 test loss: 0.0574
# Epoch 12 train loss: 0.0285 test loss: 0.058
# Epoch 13 train loss: 0.0239 test loss: 0.0704
# Epoch 14 train loss: 0.0212 test loss: 0.0703
# Epoch 15 train loss: 0.0165 test loss: 0.076
# Epoch 16 train loss: 0.0131 test loss: 0.1234
# Epoch 17 train loss: 0.0109 test loss: 0.1095
# Epoch 18 train loss: 0.0079 test loss: 0.1052
# Epoch 19 train loss: 0.0071 test loss: 0.1137
# Epoch 20 train loss: 0.0068 test loss: 0.1013
# Early stopping.
# Completed.

# %%
hist.plot(figsize=(12,6), cmap='viridis')
plt.show()

# %%
predictions_descaled, labels_descaled = inference.predict(df=test_df,
                                                          label_name='Battery',
                                                          sequence_length=sequence_length)

predictions_descaled.shape, predictions_descaled.shape

print(test_df.shape)
# Out:
# (93, 10)

# %%
print('Error on all test data:')
inference.print_loss_metrics(labels_descaled, predictions_descaled)
print('\n')
print('Error on partial test data:')
inference.print_loss_metrics(labels_descaled[:30], predictions_descaled[:30])
# Out:
# Error on all test data:
# RMSE:  228806.52
# MAE:  210825.52
#
#
# Error on partial test data:
# RMSE:  164509.46
# MAE:  138931.91

# %%
# plot predictions vs true values
df_pred = pd.DataFrame()
df_pred['predicted'] = predictions_descaled
df_pred['true'] = labels_descaled
df_pred['residual'] = labels_descaled - predictions_descaled
df_pred.plot(figsize=(12,6), cmap='viridis')
#plt.xticks(rotation=45)
#plt.xlim(0,300)
plt.xlabel('Min')
plt.ylabel('Baterry Level')
plt.legend()
plt.show()

# %%
from train import TimeSeriesDataset, TSModel
from torch.utils.data import DataLoader
import torch
import shap

# %%
background_data_size = 232
test_sample_size = 40
sequence_length = 10

# %%
shap_values = interpret.get_important_features(
    background_data_size,
    test_sample_size,
    sequence_length
)
# Out:
# Using non-full backward hooks on a Module that does not return a single Tensor or a tuple of Tensors is deprecated and will be removed in future versions. This hook will be missing some of the grad_output. Please use register_full_backward_hook to get the documented behavior.
# Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.

# %%
shap_plot = pd.DataFrame(shap_values, columns=train_df.columns.tolist())
shap_plot['Time'] = [i-11 for i in list(range(1,11))]
shap_plot.head()
# Out:
#    Time  CPU Frequency  CPU Load  Memory Usage  Wi-Fi RSSI Level  Quality  \
# 0   -10       0.000450  0.000605      0.000101          0.000091      0.0
# 1    -9       0.000597  0.000823      0.000164          0.000137      0.0
# 2    -8       0.000647  0.000848      0.000274          0.000180      0.0
# 3    -7       0.000496  0.000336      0.000485          0.000161      0.0
# 4    -6       0.000091  0.001217      0.000817          0.000079      0.0
#
#    Screen Bright   Battery  Download    Upload
# 0       0.000729  0.000219  0.000157  0.000244
# 1       0.001028  0.000456  0.000198  0.000380
# 2       0.001330  0.000969  0.000238  0.000546
# 3       0.001446  0.002561  0.000252  0.000801
# 4       0.001038  0.007143  0.000249  0.001301

# %%
shap_plot.plot.area(x='Time',figsize=(10, 6), cmap='viridis')
plt.title("Deep SHAP - Feature Importance")
plt.show()
